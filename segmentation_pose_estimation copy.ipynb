# %% [markdown]
# # EE267 Spring 2025 Term Project: Swimmer Segmentation and Pose Estimation

# %% [markdown]
# ## Objective
# Articial Intelligence (AI) has transformed computer vision, enabling machines to interpret visual data
# much like humans. Two critical techniques in this field are image segmentation and human pose
# estimation. Image segmentation isolates objects from their backgrounds, essential for tasks like sports
# analysis and medical imaging. Human pose estimation, on the other hand, detects body joints and
# movement, providing valuable insights for elds such as biomechanics and augmented reality.
#
# In this assignment, we will do the following:
# 1. Segment the swimmer from the background using Meta's Segment Anything Model (SAM).
# 2. Detect and label the swimmer's joints using a human pose estimation model of your choice
# (either YOLO or Meta Sapiens).

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Task 0: Data Pre-processing

# %% [markdown]
# ### Task 1: Swimmer Segmentation with SAM
# Description:
#
# Use Meta’s SAM model to isolate the swimmer from each frame provided.
#
# Instructions:
# 1. Load the provided dataset of swimmer images.
# 2. Apply SAM to each image to segment the swimmer, separating them from the background.
# 3. Save the segmented images for the next task.
#
# Meta SAM Github: https://github.com/facebookresearch/segment-anything

# %% [markdown]
# ### Task 2: Pose Estimation on the Segmented Swimmer
#
# Description:
#
# With the segmented swimmer images, utilize a human pose estimation model to
# detect the swimmer’s joints.
#
# Model Options:
# 1. YOLO (congured for pose estimation).
# 2. Meta Sapiens
#
# Instructions:
# 1. Choose either YOLO or Meta Sapiens for pose estimation.
# 2. Run the selected model on the segmented images to identify key joint positions.
# 3. Save images with overlaid joint positions and export joint coordinates for each frame.

# %% [markdown]
# Ultralytics YOLOv11 Pose Estimation Docs: https://docs.ultralytics.com/tasks/pose/

# %%
# Import libraries
from ultralytics import YOLO

# %%
# Initialize Pose Estimation Model
model = YOLO('models/yolo11n-pose.pt')

# %%
# Identify key joint positions
results = model.track('back_training.mp4', show=True, save=True)
# Out:
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# Cell In[376], line 2
#
#       1 # Identify key joint positions
#
# ----> 2 results = model.track('back_training.mp4', show=True, save=True)
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/engine/model.py:594, in Model.track(self, source, stream, persist, **kwargs)
#
#     592 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#
#     593 kwargs["mode"] = "track"
#
# --> 594 return self.predict(source=source, stream=stream, **kwargs)
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/engine/model.py:550, in Model.predict(self, source, stream, predictor, **kwargs)
#
#     548 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#
#     549     self.predictor.set_prompts(prompts)
#
# --> 550 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/engine/predictor.py:216, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#
#     214     return self.stream_inference(source, model, *args, **kwargs)
#
#     215 else:
#
# --> 216     return list(self.stream_inference(source, model, *args, **kwargs))
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#
#      32 try:
#
#      33     # Issuing `None` to a generator fires it up
#
#      34     with ctx_factory():
#
# ---> 35         response = gen.send(None)
#
#      37     while True:
#
#      38         try:
#
#      39             # Forward the response to our caller and get its next request
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/engine/predictor.py:297, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#
#     293     self.setup_model(model)
#
#     295 with self._lock:  # for thread-safe inference
#
#     296     # Setup source every time predict is called
#
# --> 297     self.setup_source(source if source is not None else self.args.source)
#
#     299     # Check if save_dir/ label file exists
#
#     300     if self.args.save or self.args.save_txt:
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/engine/predictor.py:257, in BasePredictor.setup_source(self, source)
#
#     247 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#
#     248 self.transforms = (
#
#     249     getattr(
#
#     250         self.model.model,
#
#    (...)
#
#     255     else None
#
#     256 )
#
# --> 257 self.dataset = load_inference_source(
#
#     258     source=source,
#
#     259     batch=self.args.batch,
#
#     260     vid_stride=self.args.vid_stride,
#
#     261     buffer=self.args.stream_buffer,
#
#     262 )
#
#     263 self.source_type = self.dataset.source_type
#
#     264 if not getattr(self, "stream", True) and (
#
#     265     self.source_type.stream
#
#     266     or self.source_type.screenshot
#
#     267     or len(self.dataset) > 1000  # many images
#
#     268     or any(getattr(self.dataset, "video_flag", [False]))
#
#     269 ):  # videos
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/data/build.py:253, in load_inference_source(source, batch, vid_stride, buffer)
#
#     251     dataset = LoadPilAndNumpy(source)
#
#     252 else:
#
# --> 253     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#
#     255 # Attach source types to the dataset
#
#     256 setattr(dataset, "source_type", source_type)
#
#
#
# File ~/Desktop/Coding Coursework/SJSU/EE 267/Project/venv/lib/python3.9/site-packages/ultralytics/data/loaders.py:342, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride)
#
#     340         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#
#     341     else:
#
# --> 342         raise FileNotFoundError(f"{p} does not exist")
#
#     344 # Define files as images or videos
#
#     345 images, videos = [], []
#
#
#
# FileNotFoundError: back_training.mp4 does not exist

# %%
# Overlay images with joint positions

# %%
# Save overlaid images, save keypoint coordinates in csv file
